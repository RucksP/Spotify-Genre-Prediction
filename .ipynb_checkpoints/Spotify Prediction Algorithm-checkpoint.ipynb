# %% [markdown]
# # Attempting to predict the genre of a song given 25 other feature vectors
#
# ## By Team TBD

# %%
# Rohan Patel
# Nasar Issa
# EJ Oyazgan
# Steven Wong
#
#
# Dataset downloaded from: 
# https://www.kaggle.com/zaheenhamidani/ultimate-spotify-tracks-db#SpotifyFeatures.csv
# Explanations for all of the features: 
# https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
# import any libraries we will use for this classification problem
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
from scipy import stats
from sklearn.cluster import KMeans

# %%
# load the raw dataset
raw_data = pd.read_csv('Data/SpotifyFeatures.csv')
raw_data
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
# Graph the raw data if we can

# %%
# Clean the data of any weird or unneccessary categories
cleaned_data = pd.read_csv('Data/CleanSpotifyData.csv')

# %%
# Normalize the Data
columns = list(cleaned_data.columns)
#remove the genre label from the data we will run k-means on
columns.remove('genre')
normalized_data = stats.zscore(cleaned_data[columns])

# %%
# Run the K-Means Algorithm on the normalized Data

kmeans = KMeans(n_clusters=20, random_state=0).fit(normalized_data)
labels = kmeans.labels_

cleaned_data['clusters'] = labels
columns.extend(['clusters'])

# %%
# the Dataframe of what songs are grouped to which clusters
clean_mean = cleaned_data.groupby(['clusters']).mean()

# %%
# Graph the Data
# PCA will be helpful here

# %%
# Group the Data
cleaned_data['genre']
# Out:
# 0         Movie
# 1         Movie
# 2         Movie
# 3         Movie
# 4         Movie
#           ...
# 232720     Soul
# 232721     Soul
# 232722     Soul
# 232723     Soul
# 232724     Soul
# Name: genre, Length: 232725, dtype: object

# %%
# See how well we did
plt.style.use('ggplot')
plots = pd.plotting.scatter_matrix(clean_mean, alpha=0.2, figsize=(50, 50))

# %%
plt.subplots(figsize=(30,20))
sns.heatmap(clean_mean.corr(), annot = True)

# %%
# Writeup
